# %%
import pandas as pd

# %%
data=pd.read_csv("DATOSLP13DEA.csv", sep=",",encoding="latin1")

# %%
data.head()
# Out:
#          Date      Time  AT-101     AT-102       CO2  DENSIDAD     FLUJO  \
# 0  12/14/2023  13:24:26  14.875  21.250002  0.724000  1.007875  0.347813
# 1  12/14/2023  13:24:56  14.875  21.250002  0.716349  1.006500  0.452813
# 2  12/14/2023  13:25:26  14.875  21.250002  0.651882  1.009500  0.380625
# 3  12/14/2023  13:25:56  14.875  21.250002  0.459085  0.995875  0.071250
# 4  12/14/2023  13:26:26  14.875  21.250002  0.266001  0.994750  0.441563
#
#     FT-101  LT-101  NIVEL_ACTIVAR  ...  Unnamed: 26  Unnamed: 27  Unnamed: 28  \
# 0  0.01628     0.0             46  ...          NaN          NaN          NaN
# 1  0.01628     0.0             46  ...          NaN          NaN          NaN
# 2  0.01628     0.0             46  ...          NaN          NaN          NaN
# 3  0.01628     0.0             46  ...          NaN          NaN          NaN
# 4  0.01628     0.0             46  ...          NaN          NaN          NaN
#
# ...

# %%
df=data.iloc[:,:25]

# %%
df.head()
# Out:
#          Date      Time  AT-101     AT-102       CO2  DENSIDAD     FLUJO  \
# 0  12/14/2023  13:24:26  14.875  21.250002  0.724000  1.007875  0.347813
# 1  12/14/2023  13:24:56  14.875  21.250002  0.716349  1.006500  0.452813
# 2  12/14/2023  13:25:26  14.875  21.250002  0.651882  1.009500  0.380625
# 3  12/14/2023  13:25:56  14.875  21.250002  0.459085  0.995875  0.071250
# 4  12/14/2023  13:26:26  14.875  21.250002  0.266001  0.994750  0.441563
#
#     FT-101  LT-101  NIVEL_ACTIVAR  ...        RQ  SE-101  SET_POINT_GAS  \
# 0  0.01628     0.0             46  ...  0.664287       0            0.0
# 1  0.01628     0.0             46  ...  0.687632       0            0.0
# 2  0.01628     0.0             46  ...  0.815077       0            0.0
# 3  0.01628     0.0             46  ...  0.982730       0            0.0
# 4  0.01628     0.0             46  ...  0.664425       0            0.0
#
#    SUSTRATO  SUSTRATO2  SV-101     TE-101     TE-102      TE-103     TE-106
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            2356 non-null   object
#  1   Time            2356 non-null   object
#  2   AT-101          2356 non-null   float64
#  3   AT-102          2356 non-null   float64
#  4   CO2             2356 non-null   float64
#  5   DENSIDAD        2356 non-null   float64
#  6   FLUJO           2356 non-null   float64
#  7   FT-101          2356 non-null   float64
#  8   LT-101          2356 non-null   float64
#  9   NIVEL_ACTIVAR   2356 non-null   int64
#  10  NIVEL_ANTIESPU  2356 non-null   int64
#  11  O2              2356 non-null   float64
#  12  PT-101          2356 non-null   float64
#  13  Q_O2            2356 non-null   float64
#  14  Q_CO2           2356 non-null   float64
#  15  RQ              2356 non-null   float64
#  16  SE-101          2356 non-null   int64
# ...

# %%
categorical = data.select_dtypes(include=['object'])  # Selecciona las columnas tipo 'object'
numeric = data.select_dtypes(include=['int', 'float'])  # Selecciona las columnas tipo 'int' o 'float'

print("Variables Categóricas:")
print(categorical)
print("\nVariables Numéricas:")
print(numeric)
# Out:
# Variables Categóricas:
#             Date      Time Unnamed: 29 Unnamed: 30  Unnamed: 31 Unnamed: 32  \
# 0     12/14/2023  13:24:26         NaN         NaN          NaN         NaN
# 1     12/14/2023  13:24:56         NaN         NaN          NaN         NaN
# 2     12/14/2023  13:25:26         NaN   Peso seco     Volumen           15
# 3     12/14/2023  13:25:56        Hora      Código  Petri vacio  Petri seco
# 4     12/14/2023  13:26:26    12:00 AM          0A      44.1619     44.3635
# ...          ...       ...         ...         ...          ...         ...
# 2351  12/15/2023   9:00:12         NaN         NaN          NaN         NaN
# 2352  12/15/2023   9:00:42         NaN         NaN          NaN         NaN
# 2353  12/15/2023   9:01:12         NaN         NaN          NaN         NaN
# 2354  12/15/2023   9:01:42         NaN         NaN          NaN         NaN
# 2355  12/15/2023   9:02:12         NaN         NaN          NaN         NaN
#
# ...

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
import numpy as np
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_classification

# %%
X_train, X_test, y_train, y_test = train_test_split(numeric, df["TE-102"], random_state=0)

# %%
Pipeline1= Pipeline([("imputer", SimpleImputer(missing_values=np.nan, strategy="median")),('scaler', StandardScaler()),
    ('svc', SVC())])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            2356 non-null   object
#  1   Time            2356 non-null   object
#  2   AT-101          2356 non-null   float64
#  3   AT-102          2356 non-null   float64
#  4   CO2             2356 non-null   float64
#  5   DENSIDAD        2356 non-null   float64
#  6   FLUJO           2356 non-null   float64
#  7   FT-101          2356 non-null   float64
#  8   LT-101          2356 non-null   float64
#  9   NIVEL_ACTIVAR   2356 non-null   int64
#  10  NIVEL_ANTIESPU  2356 non-null   int64
#  11  O2              2356 non-null   float64
#  12  PT-101          2356 non-null   float64
#  13  Q_O2            2356 non-null   float64
#  14  Q_CO2           2356 non-null   float64
#  15  RQ              2356 non-null   float64
#  16  SE-101          2356 non-null   int64
# ...

# %%
Pipeline1.fit(X_train, y_train)
# Out:
# c:\Users\Luis Vasquez\anaconda3\Lib\site-packages\sklearn\impute\_base.py:555: UserWarning: Skipping features without any observed values: ['Unnamed: 25' 'Unnamed: 26' 'Unnamed: 27' 'Unnamed: 28']. At least one non-missing value is needed for imputation with strategy='median'.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 Pipeline1.fit(X_train, y_train)
#
# File c:\Users\Luis Vasquez\anaconda3\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# ...

# %%
Pipeline1.score(X_test, y_test)

# %%
numeric
